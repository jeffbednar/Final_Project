# %%
import pandas as pd
import numpy as np

# %%
vacinations_df = pd.read_csv("country_vaccinations_raw.csv")
cases_deaths_df = pd.read_csv("worldometer_coronavirus_daily_data_raw.csv")

# %%
vacinations_df
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 4430  Zimbabwe      ZWE  2021-02-23              4041.0             4041.0
# 4431  Zimbabwe      ZWE  2021-02-24              7872.0             7872.0
# 4432  Zimbabwe      ZWE  2021-02-25             11007.0            11007.0
# 4433  Zimbabwe      ZWE  2021-02-26             12579.0            12579.0
# 4434  Zimbabwe      ZWE  2021-02-27             15705.0            15705.0
#
# ...

# %%
cleaned_vacinations_df = vacinations_df.drop(["iso_code", "source_name", "source_website", "daily_vaccinations_per_million", "people_fully_vaccinated_per_hundred", "people_vaccinated_per_hundred", "total_vaccinations_per_hundred"], axis=1)

# %%
cleaned_vacinations_df
# Out:
#        country        date  total_vaccinations  people_vaccinated  \
# 0      Albania  2021-01-10                 0.0                0.0
# 1      Albania  2021-01-11                 NaN                NaN
# 2      Albania  2021-01-12               128.0              128.0
# 3      Albania  2021-01-13               188.0              188.0
# 4      Albania  2021-01-14               266.0              266.0
# ...        ...         ...                 ...                ...
# 4430  Zimbabwe  2021-02-23              4041.0             4041.0
# 4431  Zimbabwe  2021-02-24              7872.0             7872.0
# 4432  Zimbabwe  2021-02-25             11007.0            11007.0
# 4433  Zimbabwe  2021-02-26             12579.0            12579.0
# 4434  Zimbabwe  2021-02-27             15705.0            15705.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# ...

# %%
cases_deaths_df
# Out:
#             date      country  cumulative_total_cases  daily_new_cases  \
# 0      2020-2-15  Afghanistan                     0.0              NaN
# 1      2020-2-16  Afghanistan                     0.0              NaN
# 2      2020-2-17  Afghanistan                     0.0              NaN
# 3      2020-2-18  Afghanistan                     0.0              NaN
# 4      2020-2-19  Afghanistan                     0.0              NaN
# ...          ...          ...                     ...              ...
# 82801  2021-2-22     Zimbabwe                 35862.0             66.0
# 82802  2021-2-23     Zimbabwe                 35910.0             48.0
# 82803  2021-2-24     Zimbabwe                 35960.0             50.0
# 82804  2021-2-25     Zimbabwe                 35994.0             34.0
# 82805  2021-2-26     Zimbabwe                 36044.0             50.0
#
#        active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %%
cleaned_cases_deaths_df = cases_deaths_df[cases_deaths_df["date"] > "2021-1-01"]

# %%
cleaned_cases_deaths_df
# Out:
#             date      country  cumulative_total_cases  daily_new_cases  \
# 322    2021-1-02  Afghanistan                 52709.0            123.0
# 323    2021-1-03  Afghanistan                 52909.0            200.0
# 324    2021-1-04  Afghanistan                 53011.0            102.0
# 325    2021-1-05  Afghanistan                 53105.0             94.0
# 326    2021-1-06  Afghanistan                 53207.0            102.0
# ...          ...          ...                     ...              ...
# 82801  2021-2-22     Zimbabwe                 35862.0             66.0
# 82802  2021-2-23     Zimbabwe                 35910.0             48.0
# 82803  2021-2-24     Zimbabwe                 35960.0             50.0
# 82804  2021-2-25     Zimbabwe                 35994.0             34.0
# 82805  2021-2-26     Zimbabwe                 36044.0             50.0
#
#        active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %%
combined_df = pd.merge(cleaned_vacinations_df, cleaned_cases_deaths_df, how='inner', on="country")

# %%
combined_df
# Out:
#          country      date_x  total_vaccinations  people_vaccinated  \
# 0        Albania  2021-01-10                 0.0                0.0
# 1        Albania  2021-01-10                 0.0                0.0
# 2        Albania  2021-01-10                 0.0                0.0
# 3        Albania  2021-01-10                 0.0                0.0
# 4        Albania  2021-01-10                 0.0                0.0
# ...          ...         ...                 ...                ...
# 210331  Zimbabwe  2021-02-27             15705.0            15705.0
# 210332  Zimbabwe  2021-02-27             15705.0            15705.0
# 210333  Zimbabwe  2021-02-27             15705.0            15705.0
# 210334  Zimbabwe  2021-02-27             15705.0            15705.0
# 210335  Zimbabwe  2021-02-27             15705.0            15705.0
#
#         people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...
